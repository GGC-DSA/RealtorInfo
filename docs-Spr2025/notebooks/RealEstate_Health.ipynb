# %%
import pandas as pd

# %%
df = pd.read_csv("health_24.csv")
df
# Out:
#        County  2023 General Hospital Facilities  \
# 0     APPLING                               1.0
# 1    ATKINSON                               0.0
# 2       BACON                               1.0
# 3       BAKER                               0.0
# 4     BALDWIN                               1.0
# ..        ...                               ...
# 163       NaN                               NaN
# 164       NaN                               NaN
# 165       NaN                               NaN
# 166       NaN                               NaN
# 167       NaN                               NaN
#
#     2023 General Hospital Bed Capacity  \
# 0                                   64
# 1                                    0
# 2                                   47
# 3                                    0
# 4                                  140
# ..                                 ...
# 163                                NaN
# 164                                NaN
# ...
