# %%
import pandas as pd

# %%
df = pd.read_csv('labor_24.csv')
df
# Out:
#        County 2022 Average Number of Establishments, All Industries  \
# 0     APPLING                                                549
# 1    ATKINSON                                                138
# 2       BACON                                                307
# 3       BAKER                                                 66
# 4     BALDWIN                                              1,058
# ..        ...                                                ...
# 159   GEORGIA                                            422,306
# 160       NaN                                                NaN
# 161       NaN                                                NaN
# 162       NaN                                                NaN
# 163       NaN                                                NaN
#
#     2022 Average Monthly Employment, All Industries  \
# 0                                             7,038
# 1                                             2,163
# ...
